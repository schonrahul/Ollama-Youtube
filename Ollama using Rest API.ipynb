# %% [markdown]
# # GENERATE USING OLLAMA LIBRARY

# %%
import ollama

response= ollama.generate(
    model="llama3.2:1b",
    prompt="Explain black holes simply"
)

print(response.response)
# Out:
# Black holes are really interesting objects in space, and I'll try to explain them in simple terms.
#
# **What is a black hole?**
#
# A black hole is a region in space where the gravitational pull is so strong that nothing, including light, can escape. It's formed when a massive star collapses in on itself and its gravity becomes so strong that it warps the fabric of space around it.
#
# **How does it form?**
#
# When a massive star runs out of fuel, it can't support its own weight anymore, so it collapses under its own gravity. This collapse causes a massive amount of matter to be compressed into an incredibly small space, creating an intense gravitational field. If the star is massive enough (about 3-4 times the size of our sun), its gravity will eventually become so strong that not even light can escape, making it invisible to us.
#
# **What happens near a black hole?**
#
# Everything that gets too close to a black hole gets pulled in and doesn't come out again. This is because the gravity is so strong that it warps space around the black hole, creating a "point of no return." Any object or person that crosses this point will be trapped forever.
#
# **How do scientists detect black holes?**
#
# Scientists can detect black holes by looking for several signs:
#
# 1. **X-rays and gamma rays:** Telescopes can detect X-rays and gamma rays emitted when high-energy particles are accelerated near a black hole.
# 2. **Radio waves:** Radio telescopes can detect radio waves from matter that's been torn apart by the strong gravity of a black hole.
# 3. **Star motions:** By observing the motion of stars near a suspected black hole, astronomers can determine if they're being affected by its gravity.
#
# **Some cool facts about black holes:**
#
# 1. **Supermassive black holes:** These are found at the centers of galaxies and can have billions of times more mass than our sun!
# 2. **Information paradox:** The laws of physics as we know them break down near a black hole, making it difficult to understand what happens to information that falls in.
# 3. **Event horizons:** The point of no return around a black hole is called an event horizon. Once something crosses this point, it's trapped forever.
#
# That's a basic overview of black holes! They're truly fascinating objects that continue to capture our imagination and curiosity.

# %% [markdown]
# # GENERATE USING REST API

# %%
import requests
import json

url = "http://localhost:11434/api/generate"

payload = {
    "model": "llama3.2:1b",
    "prompt": "Explain black holes simply"
}


response = requests.post(url, json=payload)

# %%
# Out:
# <Response [200]>

# %%
for i in response.iter_lines(): #ollama sends multiple json lines
    print(i)
# Out:
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.5829495Z","response":"Black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.7418155Z","response":" holes","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.7502173Z","response":" are","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.7587668Z","response":" one","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.7666594Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.7747577Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.7833414Z","response":" most","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8025107Z","response":" fascinating","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8025107Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8083181Z","response":" mysterious","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.81666Z","response":" objects","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8260764Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8400927Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8407283Z","response":" universe","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8490309Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8572762Z","response":" Here","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8652561Z","response":"\'s","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8731766Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8817964Z","response":" simple","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8900838Z","response":" explanation","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.8980048Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9064449Z","response":"**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9146274Z","response":"What","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9228469Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9311976Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9394524Z","response":" Black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9473313Z","response":" Hole","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9560595Z","response":"?","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9641353Z","response":"**\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9723539Z","response":"A","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.9806852Z","response":" black","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.98864Z","response":" hole","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:28.996739Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0054067Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0134927Z","response":" region","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0212007Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0298345Z","response":" space","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0382103Z","response":" where","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0456982Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0542934Z","response":" gravity","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0620021Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0702135Z","response":" so","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0786758Z","response":" strong","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0860137Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.0946378Z","response":" nothing","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1029236Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1112334Z","response":" including","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1193475Z","response":" light","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1272792Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1351555Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1437361Z","response":" escape","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1518396Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1599823Z","response":" It","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1680593Z","response":"\'s","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1762004Z","response":" formed","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.183918Z","response":" when","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.1923827Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2006158Z","response":" massive","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2088065Z","response":" star","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2169616Z","response":" collapses","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2250008Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2329771Z","response":" on","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2411779Z","response":" itself","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.25054Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2579259Z","response":" its","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2658026Z","response":" gravity","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2758361Z","response":" becomes","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2822144Z","response":" so","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2913325Z","response":" strong","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.2989373Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.3075132Z","response":" it","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.3150354Z","response":" war","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.3234436Z","response":"ps","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-01-11T06:29:29.
,36490,50924,11161,1,430,649,7958,3634,323,892,382,334,4266,315,5348,473,7298,57277,3947,527,3116,4595,315,3776,20349,11,1855,449,2204,6012,1473,9,3146,626,27978,5348,473,7298,96618,3459,291,505,279,18678,315,3927,9958,627,9,3146,19841,27428,535,5348,473,7298,96618,12595,520,279,19169,315,66017,11,449,32738,11990,477,1524,33151,315,3115,430,315,1057,7160,627,9,3146,100061,5364,395,5348,473,7298,96618,5348,20349,449,32738,430,4498,1990,1884,315,48317,323,2307,27428,535,3776,20349,382,644,12399,11,3776,20349,527,13918,304,3634,1405,24128,374,779,3831,430,4400,649,12731,11,323,814,617,5016,6012,1093,1567,4917,64947,11,35044,1385,11,323,36376,24527,13213,13,2435,7958,3634,323,892,304,27387,5627,11,3339,1124,1063,315,279,1455,7185,6302,304,279,15861,13],"total_duration":4833229600,"load_duration":336616200,"prompt_eval_count":30,"prompt_eval_duration":196725000,"eval_count":503,"eval_duration":4000451700}'

# %%
output= ""

for i in response.iter_lines():
    if i:
        data = json.loads(i.decode("utf-8"))
        if "response" in data:
            output+=data["response"]
        if data.get("done"):
            break


print(output)
# Out:
# Black holes are one of the most fascinating and mysterious objects in the universe. Here's a simple explanation:
#
# **What is a Black Hole?**
#
# A black hole is a region in space where the gravity is so strong that nothing, including light, can escape. It's formed when a massive star collapses in on itself and its gravity becomes so strong that it warps the fabric of spacetime around it.
#
# **How does it Form?**
#
# When a massive star runs out of fuel, it collapses under its own gravity, causing a massive amount of matter to be compressed into an incredibly small space. The point of no return, called the event horizon, forms when the gravity becomes so strong that not even light can escape. Once something crosses the event horizon, it's trapped by the black hole's gravity.
#
# **Properties of Black Holes**
#
# Black holes have some amazing properties:
#
# * **Event Horizon**: The point of no return around a black hole.
# * **Singularity**: A point at the center of a black hole where the gravity is infinite.
# * **Ergosphere**: A region around a rotating black hole where the rotation creates a kind of "gravitational drag."
# * **Hawking Radiation**: A theoretical prediction that black holes slowly lose mass over time due to quantum effects.
#
# **How Black Holes Affect Space and Time**
#
# Black holes have a profound effect on space and time:
#
# * **Gravitational Lensing**: The bending of light around a massive object, like a black hole.
# * **Time Dilation**: Time appears to slow down near a black hole due to its strong gravity.
# * **Frame-Dragging**: The rotation of a black hole creates a kind of "gravitational drag" that can affect space and time.
#
# **Types of Black Holes**
#
# There are four types of black holes, each with different properties:
#
# * **Stellar Black Holes**: Formed from the collapse of individual stars.
# * **Supermassive Black Holes**: Found at the centers of galaxies, with masses millions or even billions of times that of our sun.
# * **Intermediate-Mass Black Holes**: Black holes with masses that fall between those of stellar and supermassive black holes.
#
# In summary, black holes are regions in space where gravity is so strong that nothing can escape, and they have unique properties like event horizons, singularities, and ergospheres. They affect space and time in fascinating ways, making them some of the most interesting objects in the universe.

# %% [markdown]
# # LIST USING OLLAMA LIBRARY

# %%
import ollama

models = ollama.list()


models   # models with details of models.
# Out:
# ListResponse(models=[Model(model='sentiment:latest', modified_at=datetime.datetime(2026, 1, 11, 9, 15, 59, 711444, tzinfo=TzInfo(19800)), digest='b8b53cc75dcf6bbb8bd779119920f48343c4ccc2e31869a51a512f443ebd63dd', size=1321099145, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.2B', quantization_level='Q8_0')), Model(model='llama3.2:1b', modified_at=datetime.datetime(2026, 1, 11, 8, 23, 31, 304903, tzinfo=TzInfo(19800)), digest='baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878', size=1321098329, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.2B', quantization_level='Q8_0')), Model(model='qwen3:8b', modified_at=datetime.datetime(2026, 1, 9, 22, 0, 28, 883897, tzinfo=TzInfo(19800)), digest='500a1f067a9f782620b40bee6f7b0c89e17ae61f686b92c24933e4ca4b2b8b41', size=5225388164, details=ModelDetails(parent_model='', format='gguf', family='qwen3', families=['qwen3'], parameter_size='8.2B', quantization_level='Q4_K_M')), Model(model='gemma3:4b', modified_at=datetime.datetime(2026, 1, 9, 10, 50, 42, 194779, tzinfo=TzInfo(19800)), digest='a2af6cc3eb7fa8be8504abaf9b04e88f17a119ec3f04a3addf55f92841195f5a', size=3338801804, details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='4.3B', quantization_level='Q4_K_M'))])

# %%
for model in models["models"]:  # iterate over models.
    print(model["model"])
# Out:
# sentiment:latest
# llama3.2:1b
# qwen3:8b
# gemma3:4b

# %% [markdown]
# # LIST USING REST API

# %%
import requests

url = "http://localhost:11434/api/tags"

r = requests.get(url)
data = r.json() #extracting the JSON data from the HTTP response and converting it into a Python object


data  # entire data.
# Out:
# {'models': [{'name': 'sentiment:latest',
#    'model': 'sentiment:latest',
#    'modified_at': '2026-01-11T09:15:59.7114444+05:30',
#    'size': 1321099145,
#    'digest': 'b8b53cc75dcf6bbb8bd779119920f48343c4ccc2e31869a51a512f443ebd63dd',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '1.2B',
#     'quantization_level': 'Q8_0'}},
#   {'name': 'llama3.2:1b',
#    'model': 'llama3.2:1b',
#    'modified_at': '2026-01-11T08:23:31.3049032+05:30',
#    'size': 1321098329,
#    'digest': 'baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '1.2B',
#     'quantization_level': 'Q8_0'}},
#   {'name': 'qwen3:8b',
#    'model': 'qwen3:8b',
#    'modified_at': '2026-01-09T22:00:28.8838977+05:30',
#    'size': 5225388164,
#    'digest': '500a1f067a9f782620b40bee6f7b0c89e17ae61f686b92c24933e4ca4b2b8b41',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'qwen3',
#     'families': ['qwen3'],
#     'parameter_size': '8.2B',
#     'quantization_level': 'Q4_K_M'}},
#   {'name': 'gemma3:4b',
#    'model': 'gemma3:4b',
#    'modified_at': '2026-01-09T10:50:42.1947792+05:30',
#    'size': 3338801804,
#    'digest': 'a2af6cc3eb7fa8be8504abaf9b04e88f17a119ec3f04a3addf55f92841195f5a',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'gemma3',
#     'families': ['gemma3'],
#     'parameter_size': '4.3B',
#     'quantization_level': 'Q4_K_M'}}]}

# %%
for model in data["models"]:
    print(model["name"])
# Out:
# sentiment:latest
# llama3.2:1b
# qwen3:8b
# gemma3:4b
